# %%
# !pip install -U "huggingface_hub[cli]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 13.3 MB/s eta 0:00:00
# ...

# %%
# !huggingface-cli download sentence-transformers/clip-ViT-B-32
# Out:
# Consider using `hf_transfer` for faster downloads. This solution comes with some limitations. See https://huggingface.co/docs/huggingface_hub/hf_transfer for more details.
# Fetching 11 files:   0%|                                 | 0/11 [00:00<?, ?it/s]downloading https://huggingface.co/sentence-transformers/clip-ViT-B-32/resolve/61c3f1c0c7fbd01c285c063696513d859cad52eb/.gitattributes to /home/repl/.cache/huggingface/hub/tmp_o51ag5o
#
# ...
# Fetching 11 files: 100%|███████████████████████| 11/11 [00:00<00:00, 224.94it/s]
# /home/repl/.cache/huggingface/hub/models--sentence-transformers--clip-ViT-B-32/snapshots/61c3f1c0c7fbd01c285c063696513d859cad52eb

# %%
# !huggingface-cli download sentence-transformers/clip-ViT-B-32-multilingual-v1
# Out:
# Consider using `hf_transfer` for faster downloads. This solution comes with some limitations. See https://huggingface.co/docs/huggingface_hub/hf_transfer for more details.
# Fetching 15 files:   0%|                                 | 0/15 [00:00<?, ?it/s]downloading https://huggingface.co/sentence-transformers/clip-ViT-B-32-multilingual-v1/resolve/200b64f20b3cef15ade0d31b1392519a46024087/.gitattributes to /home/repl/.cache/huggingface/hub/tmpyuu_h5qq
#
# .gitattributes: 100%|███████████████████████████| 690/690 [00:00<00:00, 176kB/s]
# downloading https://huggingface.co/sentence-transformers/clip-ViT-B-32-multilingual-v1/resolve/200b64f20b3cef15ade0d31b1392519a46024087/tf_model.h5 to /home/repl/.cache/huggingface/hub/tmp2grmjt20
#
# tf_model.h5:   0%|                                   | 0.00/539M [00:00<?, ?B/s]
# tf_model.h5:   2%|▌                          | 10.5M/539M [00:00<00:05, 103MB/s]
# tf_model.h5:   6%|█▌                        | 31.5M/539M [00:00<00:08, 62.8MB/s]
# ...
